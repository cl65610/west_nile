# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import math
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/TerryONeill/west_nile/west_nile/assets/train_weather_join.csv')

# %%
## here are just a few ways to familiarize ourselves with the dataframe

print 'Shape of Dataframe:\n', df.shape
print
print 'Datatypes of Columns:\n', df.dtypes
print
print 'Null Values for Each Column:\n', df.isnull().sum()
# Out:
# Shape of Dataframe:
# (10506, 21)
#
# Datatypes of Columns:
# Date                object
# Species              int64
# Trap                 int64
# Latitude           float64
# Longitude          float64
# AddressAccuracy      int64
# NumMosquitos         int64
# WnvPresent           int64
# day                  int64
# month                int64
# year                 int64
# Tmax               float64
# Tmin               float64
# Tavg               float64
# Depart             float64
# DewPoint           float64
# PrecipTotal        float64
# Sunrise            float64
# Sunset             float64
# month_weather      float64
# day_weather        float64
# dtype: object
#
# Null Values for Each Column:
# Date               0
# Species            0
# Trap               0
# Latitude           0
# Longitude          0
# AddressAccuracy    0
# NumMosquitos       0
# WnvPresent         0
# day                0
# month              0
# year               0
# Tmax               0
# Tmin               0
# Tavg               0
# Depart             0
# DewPoint           0
# PrecipTotal        0
# Sunrise            0
# Sunset             0
# month_weather      0
# day_weather        0
# dtype: int64

# %%
## checking out the head of the dataframe
df.head()
# Out:
#          Date  Species  Trap   Latitude  Longitude  AddressAccuracy  \
# 0  2007-05-29        2     1  41.954690 -87.800991                9
# 1  2007-05-29        3     1  41.954690 -87.800991                9
# 2  2007-05-29        3     6  41.994991 -87.769279                9
# 3  2007-05-29        2    13  41.974089 -87.824812                8
# 4  2007-05-29        3    13  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  day  month     ...       Tmax  Tmin  Tavg  \
# 0             1           0  179      5     ...       88.0  62.5  75.5
# 1             1           0  179      5     ...       88.0  62.5  75.5
# 2             1           0  179      5     ...       88.0  62.5  75.5
# 3             1           0  179      5     ...       88.0  62.5  75.5
# 4             4           0  179      5     ...       88.0  62.5  75.5
#
#    Depart  DewPoint  PrecipTotal  Sunrise  Sunset  month_weather  day_weather
# 0    10.0      58.5          0.0    421.0  1917.0            5.0        179.0
# 1    10.0      58.5          0.0    421.0  1917.0            5.0        179.0
# 2    10.0      58.5          0.0    421.0  1917.0            5.0        179.0
# 3    10.0      58.5          0.0    421.0  1917.0            5.0        179.0
# 4    10.0      58.5          0.0    421.0  1917.0            5.0        179.0
#
# [5 rows x 21 columns]

# %%
## I am listing specifically the weather columns that I want to perform PCA on so I can
## make a dataframe of just these columns
pca_cols = ['Tmax', 'Tmin', 'Tavg', 'Depart', 'DewPoint', 'month_weather', 'day_weather']

## creating the dataframe with the specified columns
pca_prep = df[pca_cols]
pca_prep.head()
# Out:
#    Tmax  Tmin  Tavg  Depart  DewPoint  month_weather  day_weather
# 0  88.0  62.5  75.5    10.0      58.5            5.0        179.0
# 1  88.0  62.5  75.5    10.0      58.5            5.0        179.0
# 2  88.0  62.5  75.5    10.0      58.5            5.0        179.0
# 3  88.0  62.5  75.5    10.0      58.5            5.0        179.0
# 4  88.0  62.5  75.5    10.0      58.5            5.0        179.0

# %%
from sklearn import preprocessing


##Standardizing all the columns
Xstand = preprocessing.StandardScaler().fit_transform(pca_prep)
Xstand
# Out:
# array([[ 0.73533201, -0.15323081,  0.33197309, ..., -0.15032138,
#         -2.52200851, -2.16470087],
#        [ 0.73533201, -0.15323081,  0.33197309, ..., -0.15032138,
#         -2.52200851, -2.16470087],
#        [ 0.73533201, -0.15323081,  0.33197309, ..., -0.15032138,
#         -2.52200851, -2.16470087],
#        ...,
#        [-0.83617307, -1.48892293, -1.20894883, ..., -0.98269898,
#          1.22462913,  1.60879562],
#        [-0.83617307, -1.48892293, -1.20894883, ..., -0.98269898,
#          1.22462913,  1.60879562],
#        [-0.83617307, -1.48892293, -1.20894883, ..., -0.98269898,
#          1.22462913,  1.60879562]])

# %%
## creating the covariance matrix - this explains the variance between the different
## features within our dataframe

## for example, the value in the i,j position within the matrix explains the variance
## between the ith and the jth elements of a random vector, or between our features
cov_mat = np.cov(Xstand.T)

## creating my eigenvalues and corresponding eigenvectors
eigenValues, eigenVectors = np.linalg.eig(cov_mat)

# %%
print eigenValues 
print
print
print eigenVectors 
## each eigenvector has 8 components - stemming from 8 total features
# Out:
# [  4.31191511e+00   2.06173206e+00   3.45251431e-01   1.49400131e-01
#    9.59255074e-02   2.70656744e-04   3.61714608e-02]
#
#
# [[ 0.4462216   0.04926796  0.5382843  -0.37253578  0.40098279 -0.44876261
#    0.08803962]
#  [ 0.44937231  0.09876047 -0.42814283 -0.25024524 -0.61743087 -0.40137224
#   -0.00783516]
#  [ 0.47361977  0.07636571  0.08609183 -0.34100656 -0.08410185  0.79841381
#    0.04021914]
#  [ 0.42505546 -0.1939785   0.40319188  0.72587161 -0.29769264  0.00462452
#   -0.06003848]
#  [ 0.43763618  0.0633152  -0.57909405  0.32206294  0.59977796  0.00130228
#   -0.07520643]
#  [ 0.03277161 -0.68601013 -0.03929831 -0.22037507  0.04236158 -0.00448052
#   -0.69021157]
#  [ 0.03692672 -0.6853765  -0.1416826  -0.05594312  0.0277452   0.00216112
#    0.71057541]]

# %%
## creating the eigenpairs - just pairing the eigenvalue with its eigenvector
eigenPairs = [(np.abs(eigenValues[i]), eigenVectors[:,i]) for i in range(len(eigenValues))]

## sort in ascending order and then reverse to descending (for clarification's sake)
eigenPairs.sort()
eigenPairs.reverse()

## loop through the eigenpairs and printing out the first row (eigenvalue)
## this is also seen in the code block above but just wanted to loop through again
## as it is a bit more clear like this
## I am also creating a list of the eigenvalues in ascending order to be able to reference it
sort_values = []
for i in eigenPairs:
    print i[0]
    sort_values.append(i[0])
    
sort_values
# Out:
# 4.31191510665
# 2.06173205605
# 0.34525143086
# 0.14940013089
# 0.0959255073613
# 0.0361714608117
# 0.000270656744141
# [4.3119151066452091,
#  2.0617320560458707,
#  0.34525143085954041,
#  0.14940013088967524,
#  0.095925507361295334,
#  0.036171460811714726,
#  0.00027065674414105507]

# %%
## we have the eigenvalues above showing us feature correlation explanation, but it helps
## to see the cumulative variance explained as well, which i can show below

## need to sum the eigen values to get percentages
sumEigenvalues = sum(eigenValues)

## this is a percentage explanation
variance_explained = [(i/sumEigenvalues)*100 for i in sort_values]
variance_explained
# Out:
# [61.592924037023657,
#  29.450511610728398,
#  4.9316938364192886,
#  2.1340844347393855,
#  1.3702339545163413,
#  0.5166859696867957,
#  0.0038661568861355204]

# %%
### based on the above results, it seems that sticking to 3 features would be ideal
## this can very easily be manipulated by changing n_components adn then adding/subtracting
## columns to the dataframe in the code block below

## instantiate
pca = PCA(n_components = 4)

## fit and transform the standardized data
pca_cols = pca.fit_transform(Xstand)

# %%
## going to organize the columns into dataframe for organization
pca_df = pd.DataFrame(pca_cols, columns = ['pca1', 'pca2', 'pca3', 'pca4'])

##previewing dataframe
print pca_df.shape
pca_df.head()
# Out:
# (10506, 4)
#        pca1      pca2      pca3      pca4
# 0 -0.663872  3.033573 -1.434144  1.092123
# 1 -0.663872  3.033573 -1.434144  1.092123
# 2 -0.663872  3.033573 -1.434144  1.092123
# 3 -0.663872  3.033573 -1.434144  1.092123
# 4 -0.663872  3.033573 -1.434144  1.092123

# %%
## Here I am joining the initial dataframe and the newly created pca dataframe
## together to move forward with

joined_pca = df.join(pca_df)

# %%
## checking on the dataframe
joined_pca
# Out:
#              Date  Species  Trap   Latitude  Longitude  AddressAccuracy  \
# 0      2007-05-29        2     1  41.954690 -87.800991                9
# 1      2007-05-29        3     1  41.954690 -87.800991                9
# 2      2007-05-29        3     6  41.994991 -87.769279                9
# 3      2007-05-29        2    13  41.974089 -87.824812                8
# 4      2007-05-29        3    13  41.974089 -87.824812                8
# 5      2007-05-29        3    32  41.921600 -87.666455                8
# 6      2007-05-29        3    33  41.891118 -87.654491                8
# 7      2007-05-29        2    35  41.867108 -87.654224                8
# 8      2007-05-29        3    35  41.867108 -87.654224                8
# 9      2007-05-29        3    36  41.896282 -87.655232                8
# 10     2007-05-29        2    37  41.919343 -87.694259                8
# 11     2007-05-29        2    39  41.921965 -87.632085                8
# 12     2007-05-29        3    39  41.921965 -87.632085                8
# 13     2007-05-29        2    65  41.688324 -87.676709                8
# 14     2007-05-29        3    65  41.688324 -87.676709                8
# 15     2007-05-29        3    69  41.862292 -87.648860                8
# 16     2007-05-29        3    71  41.720848 -87.666014                9
# 17     2007-05-29        3    74  41.731922 -87.677512                8
# 18     2007-05-29        1    74  41.731922 -87.677512                8
# 19     2007-05-29        2    84  41.891126 -87.611560                5
# 20     2007-05-29        3    84  41.891126 -87.611560                5
# 21     2007-05-29        2    89  41.999129 -87.795585                8
# 22     2007-05-29        2    94  42.017430 -87.687769                8
# 23     2007-05-29        3    99  41.907645 -87.760886                8
# 24     2007-05-29        3   105  41.732984 -87.649642                8
# 25     2007-06-05        2     1  41.954690 -87.800991                9
# 26     2007-06-05        3     1  41.954690 -87.800991                9
# 27     2007-06-05        1     1  41.954690 -87.800991                9
# 28     2007-06-05        2    13  41.974089 -87.824812                8
# 29     2007-06-05        3    13  41.974089 -87.824812                8
# ...           ...      ...   ...        ...        ...              ...
# 10476  2013-09-26        2    78  41.750498 -87.605294                5
# 10477  2013-09-26        3    78  41.750498 -87.605294                5
# 10478  2013-09-26        1    78  41.750498 -87.605294                5
# 10479  2013-09-26        1    19  41.984809 -87.728492                8
# 10480  2013-09-26        2   117  41.659112 -87.538693                8
# 10481  2013-09-26        3   117  41.659112 -87.538693                8
# 10482  2013-09-26        1   117  41.659112 -87.538693                8
# 10483  2013-09-26        3     8  41.992478 -87.862995                8
# 10484  2013-09-26        2   134  41.974689 -87.890615                9
# 10485  2013-09-26        2   134  41.974689 -87.890615                9
# 10486  2013-09-26        1   134  41.974689 -87.890615                9
# 10487  2013-09-26        1   134  41.974689 -87.890615                9
# 10488  2013-09-26        1   134  41.974689 -87.890615                9
# 10489  2013-09-26        1   134  41.974689 -87.890615                9
# 10490  2013-09-26        2   118  41.925198 -87.746381                8
# 10491  2013-09-26        2   119  41.973845 -87.805059                9
# 10492  2013-09-26        1   119  41.973845 -87.805059                9
# 10493  2013-09-26        2   121  41.743402 -87.731435                8
# 10494  2013-09-26        2   123  41.728495 -87.600963                5
# 10495  2013-09-26        1   123  41.728495 -87.600963                5
# 10496  2013-09-26        2   120  41.947227 -87.671457                9
# 10497  2013-09-26        2   122  41.793818 -87.654234                5
# 10498  2013-09-26        2   126  41.904194 -87.756155                9
# 10499  2013-09-26        1   126  41.904194 -87.756155                9
# 10500  2013-09-26        2   124  41.951866 -87.725057                8
# 10501  2013-09-26        2    25  41.763733 -87.742302                8
# 10502  2013-09-26        2   127  41.987280 -87.666066                8
# 10503  2013-09-26        2   128  41.912563 -87.668055                9
# 10504  2013-09-26        2   129  42.009876 -87.807277                9
# 10505  2013-09-26        2   130  41.776428 -87.627096                8
#
#        NumMosquitos  WnvPresent  day  month    ...     DewPoint  PrecipTotal  \
# 0                 1           0  179      5    ...         58.5        0.000
# 1                 1           0  179      5    ...         58.5        0.000
# 2                 1           0  179      5    ...         58.5        0.000
# 3                 1           0  179      5    ...         58.5        0.000
# 4                 4           0  179      5    ...         58.5        0.000
# 5                 2           0  179      5    ...         58.5        0.000
# 6                 1           0  179      5    ...         58.5        0.000
# 7                 1           0  179      5    ...         58.5        0.000
# 8                 2           0  179      5    ...         58.5        0.000
# 9                 1           0  179      5    ...         58.5        0.000
# 10                1           0  179      5    ...         58.5        0.000
# 11                2           0  179      5    ...         58.5        0.000
# 12                3           0  179      5    ...         58.5        0.000
# 13                1           0  179      5    ...         58.5        0.000
# 14                1           0  179      5    ...         58.5        0.000
# 15                1           0  179      5    ...         58.5        0.000
# 16                3           0  179      5    ...         58.5        0.000
# 17                5           0  179      5    ...         58.5        0.000
# 18                1           0  179      5    ...         58.5        0.000
# 19                1           0  179      5    ...         58.5        0.000
# 20                2           0  179      5    ...         58.5        0.000
# 21                1           0  179      5    ...         58.5        0.000
# 22                1           0  179      5    ...         58.5        0.000
# 23                1           0  179      5    ...         58.5        0.000
# 24                1           0  179      5    ...         58.5        0.000
# 25                3           0  185      6    ...         47.5        0.345
# 26                5           0  185      6    ...         47.5        0.345
# 27                1           0  185      6    ...         47.5        0.345
# 28                1           0  185      6    ...         47.5        0.345
# 29                2           0  185      6    ...         47.5        0.345
# ...             ...         ...  ...    ...    ...          ...          ...
# 10476             2           0  296      9    ...         52.0        0.000
# 10477             1           0  296      9    ...         52.0        0.000
# 10478             1           0  296      9    ...         52.0        0.000
# 10479             5           0  296      9    ...         52.0        0.000
# 10480             5           0  296      9    ...         52.0        0.000
# 10481             5           0  296      9    ...         52.0        0.000
# 10482             4           0  296      9    ...         52.0        0.000
# 10483             1           0  296      9    ...         52.0        0.000
# 10484            39           1  296      9    ...         52.0        0.000
# 10485             4           0  296      9    ...         52.0        0.000
# 10486            16           0  296      9    ...         52.0        0.000
# 10487             9           0  296      9    ...         52.0        0.000
# 10488            11           0  296      9    ...         52.0        0.000
# 10489             1           0  296      9    ...         52.0        0.000
# 10490             1           0  296      9    ...         52.0        0.000
# 10491            11           0  296      9    ...         52.0        0.000
# 10492             1           0  296      9    ...         52.0        0.000
# 10493             3           0  296      9    ...         52.0        0.000
# 10494             7           0  296      9    ...         52.0        0.000
# 10495             1           0  296      9    ...         52.0        0.000
# 10496             3           0  296      9    ...         52.0        0.000
# 10497             8           0  296      9    ...         52.0        0.000
# 10498            13           0  296      9    ...         52.0        0.000
# 10499             5           0  296      9    ...         52.0        0.000
# 10500             3           0  296      9    ...         52.0        0.000
# 10501             6           1  296      9    ...         52.0        0.000
# 10502             5           0  296      9    ...         52.0        0.000
# 10503             1           0  296      9    ...         52.0        0.000
# 10504             5           0  296      9    ...         52.0        0.000
# 10505             1           0  296      9    ...         52.0        0.000
#
#        Sunrise  Sunset  month_weather  day_weather      pca1      pca2  \
# 0        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 1        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 2        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 3        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 4        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 5        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 6        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 7        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 8        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 9        421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 10       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 11       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 12       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 13       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 14       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 15       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 16       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 17       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 18       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 19       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 20       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 21       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 22       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 23       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 24       421.0  1917.0            5.0        179.0 -0.663872  3.033573
# 25       417.0  1923.0            6.0        185.0  4.497522  2.219006
# 26       417.0  1923.0            6.0        185.0  4.497522  2.219006
# 27       417.0  1923.0            6.0        185.0  4.497522  2.219006
# 28       417.0  1923.0            6.0        185.0  4.497522  2.219006
# 29       417.0  1923.0            6.0        185.0  4.497522  2.219006
# ...        ...     ...            ...          ...       ...       ...
# 10476    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10477    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10478    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10479    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10480    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10481    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10482    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10483    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10484    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10485    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10486    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10487    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10488    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10489    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10490    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10491    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10492    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10493    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10494    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10495    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10496    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10497    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10498    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10499    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10500    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10501    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10502    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10503    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10504    543.0  1742.0            9.0        296.0  1.928283 -2.293292
# 10505    543.0  1742.0            9.0        296.0  1.928283 -2.293292
#
#            pca3      pca4
# 0     -1.434144  1.092123
# 1     -1.434144  1.092123
# 2     -1.434144  1.092123
# 3     -1.434144  1.092123
# 4     -1.434144  1.092123
# 5     -1.434144  1.092123
# 6     -1.434144  1.092123
# 7     -1.434144  1.092123
# 8     -1.434144  1.092123
# 9     -1.434144  1.092123
# 10    -1.434144  1.092123
# 11    -1.434144  1.092123
# 12    -1.434144  1.092123
# 13    -1.434144  1.092123
# 14    -1.434144  1.092123
# 15    -1.434144  1.092123
# 16    -1.434144  1.092123
# 17    -1.434144  1.092123
# 18    -1.434144  1.092123
# 19    -1.434144  1.092123
# 20    -1.434144  1.092123
# 21    -1.434144  1.092123
# 22    -1.434144  1.092123
# 23    -1.434144  1.092123
# 24    -1.434144  1.092123
# 25     0.036809  0.717634
# 26     0.036809  0.717634
# 27     0.036809  0.717634
# 28     0.036809  0.717634
# 29     0.036809  0.717634
# ...         ...       ...
# 10476 -0.392450  0.449060
# 10477 -0.392450  0.449060
# 10478 -0.392450  0.449060
# 10479 -0.392450  0.449060
# 10480 -0.392450  0.449060
# 10481 -0.392450  0.449060
# 10482 -0.392450  0.449060
# 10483 -0.392450  0.449060
# 10484 -0.392450  0.449060
# 10485 -0.392450  0.449060
# 10486 -0.392450  0.449060
# 10487 -0.392450  0.449060
# 10488 -0.392450  0.449060
# 10489 -0.392450  0.449060
# 10490 -0.392450  0.449060
# 10491 -0.392450  0.449060
# 10492 -0.392450  0.449060
# 10493 -0.392450  0.449060
# 10494 -0.392450  0.449060
# 10495 -0.392450  0.449060
# 10496 -0.392450  0.449060
# 10497 -0.392450  0.449060
# 10498 -0.392450  0.449060
# 10499 -0.392450  0.449060
# 10500 -0.392450  0.449060
# 10501 -0.392450  0.449060
# 10502 -0.392450  0.449060
# 10503 -0.392450  0.449060
# 10504 -0.392450  0.449060
# 10505 -0.392450  0.449060
#
# [10506 rows x 25 columns]

# %%
## Now that I have the PCA columns added on, I want to change the index to the date

## first i need to change the column to date time format
joined_pca['Date'] = pd.to_datetime(joined_pca['Date'])

## Now I set Date as the index. Inplace=True will modify the original object

## commenting the remaking of the index for now to keep a numeric index

##joined_pca.set_index('Date', drop = True, inplace = True)

# %%
## checking out the head
joined_pca.head()
# Out:
#         Date  Species  Trap   Latitude  Longitude  AddressAccuracy  \
# 0 2007-05-29        2     1  41.954690 -87.800991                9
# 1 2007-05-29        3     1  41.954690 -87.800991                9
# 2 2007-05-29        3     6  41.994991 -87.769279                9
# 3 2007-05-29        2    13  41.974089 -87.824812                8
# 4 2007-05-29        3    13  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  day  month    ...     DewPoint  PrecipTotal  \
# 0             1           0  179      5    ...         58.5          0.0
# 1             1           0  179      5    ...         58.5          0.0
# 2             1           0  179      5    ...         58.5          0.0
# 3             1           0  179      5    ...         58.5          0.0
# 4             4           0  179      5    ...         58.5          0.0
#
#    Sunrise  Sunset  month_weather  day_weather      pca1      pca2      pca3  \
# 0    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 1    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 2    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 3    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 4    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
#
#        pca4
# 0  1.092123
# 1  1.092123
# 2  1.092123
# 3  1.092123
# 4  1.092123
#
# [5 rows x 25 columns]

# %% [markdown]
# # Baseline KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

X = joined_pca.drop('WnvPresent', axis = 1)
y = joined_pca.WnvPresent

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3)

knn = KNeighborsClassifier()

def evaluate_model(estimator, title):
    model = estimator.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc_score = accuracy_score(y_test, y_pred)
    con_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    print "Accuracy Score:", acc_score.round(8)
    print
    print "Confusion Matrix:\n", con_matrix
    print
    print "Classification Report:\n", class_report

# %%
evaluate_model(knn, 'KNN')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-84d805c9ed09> in <module>()
# ----> 1 evaluate_model(knn, 'KNN')
#
# <ipython-input-19-b61fdfbe9d5e> in evaluate_model(estimator, title)
#      12
#      13 def evaluate_model(estimator, title):
# ---> 14     model = estimator.fit(X_train, y_train)
#      15     y_pred = model.predict(X_test)
#      16     acc_score = accuracy_score(y_test, y_pred)
#
# /Users/TerryONeill/anaconda/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in fit(self, X, y)
#     776         """
#     777         if not isinstance(X, (KDTree, BallTree)):
# --> 778             X, y = check_X_y(X, y, "csr", multi_output=True)
#     779
#     780         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /Users/TerryONeill/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     508     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     509                     ensure_2d, allow_nd, ensure_min_samples,
# --> 510                     ensure_min_features, warn_on_dtype, estimator)
#     511     if multi_output:
#     512         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /Users/TerryONeill/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     391         # make sure we acually converted to numeric:
#     392         if dtype_numeric and array.dtype.kind == "O":
# --> 393             array = array.astype(np.float64)
#     394         if not allow_nd and array.ndim >= 3:
#     395             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# TypeError: float() argument must be a string or a number

# %%
params = {'n_neighbors':range(1, 300)}

knn = KNeighborsClassifier()

knn_gscv = GridSearchCV(knn, param_grid = params, cv = 5, n_jobs = -1, verbose = 1)
knn_fit = knn_gscv.fit(X, y)
print knn_fit.best_score_
print
print knn_fit.best_estimator_
print
print knn_fit.best_params_

# %%
## now i am going to export the dataframe as a csv file

joined_pca.to_csv('/Users/TerryONeill/west_nile/west_nile/assets/joined_pca.csv')

# %%
joined_pca.head()
# Out:
#         Date  Species  Trap   Latitude  Longitude  AddressAccuracy  \
# 0 2007-05-29        2     1  41.954690 -87.800991                9
# 1 2007-05-29        3     1  41.954690 -87.800991                9
# 2 2007-05-29        3     6  41.994991 -87.769279                9
# 3 2007-05-29        2    13  41.974089 -87.824812                8
# 4 2007-05-29        3    13  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  day  month    ...     DewPoint  PrecipTotal  \
# 0             1           0  179      5    ...         58.5          0.0
# 1             1           0  179      5    ...         58.5          0.0
# 2             1           0  179      5    ...         58.5          0.0
# 3             1           0  179      5    ...         58.5          0.0
# 4             4           0  179      5    ...         58.5          0.0
#
#    Sunrise  Sunset  month_weather  day_weather      pca1      pca2      pca3  \
# 0    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 1    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 2    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 3    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
# 4    421.0  1917.0            5.0        179.0 -0.663872  3.033573 -1.434144
#
#        pca4
# 0  1.092123
# 1  1.092123
# 2  1.092123
# 3  1.092123
# 4  1.092123
#
# [5 rows x 25 columns]

# %% [markdown]
# # Test Data PCA

# %%
final_df = pd.read_csv('/Users/TerryONeill/west_nile/west_nile/assets/final_df.csv')
print final_df.shape
final_df.head()
# Out:
# (116293, 19)
#          Date  Species  Trap  Latitude  Longitude  AddressAccuracy  day  \
# 0  2008-06-11        2     1  41.95469 -87.800991                9  191
# 1  2008-06-11        3     1  41.95469 -87.800991                9  191
# 2  2008-06-11        1     1  41.95469 -87.800991                9  191
# 3  2008-06-11        4     1  41.95469 -87.800991                9  191
# 4  2008-06-11        6     1  41.95469 -87.800991                9  191
#
#    month  year  Tmax  Tmin  Tavg  Depart  DewPoint  PrecipTotal  Sunrise  \
# 0      6  2008  86.0  63.5  75.0     7.0      55.5          0.0    416.0
# 1      6  2008  86.0  63.5  75.0     7.0      55.5          0.0    416.0
# 2      6  2008  86.0  63.5  75.0     7.0      55.5          0.0    416.0
# 3      6  2008  86.0  63.5  75.0     7.0      55.5          0.0    416.0
# 4      6  2008  86.0  63.5  75.0     7.0      55.5          0.0    416.0
#
#    Sunset  month_weather  day_weather
# 0  1926.0            6.0        191.0
# 1  1926.0            6.0        191.0
# 2  1926.0            6.0        191.0
# 3  1926.0            6.0        191.0
# 4  1926.0            6.0        191.0

# %%
## I am listing specifically the weather columns that I want to perform PCA on so I can
## make a dataframe of just these columns
pca_cols = ['Tmax', 'Tmin', 'Tavg', 'Depart', 'DewPoint', 'month_weather', 'day_weather']

## creating the dataframe with the specified columns
pca_prep = final_df[pca_cols]
pca_prep.head()
# Out:
#    Tmax  Tmin  Tavg  Depart  DewPoint  month_weather  day_weather
# 0  86.0  63.5  75.0     7.0      55.5            6.0        191.0
# 1  86.0  63.5  75.0     7.0      55.5            6.0        191.0
# 2  86.0  63.5  75.0     7.0      55.5            6.0        191.0
# 3  86.0  63.5  75.0     7.0      55.5            6.0        191.0
# 4  86.0  63.5  75.0     7.0      55.5            6.0        191.0

# %%
from sklearn import preprocessing


##Standardizing all the columns
Xstand = preprocessing.StandardScaler().fit_transform(pca_prep)
Xstand
# Out:
# array([[ 0.63932333,  0.16897014,  0.45734427, ..., -0.28246883,
#         -1.52016095, -1.69224449],
#        [ 0.63932333,  0.16897014,  0.45734427, ..., -0.28246883,
#         -1.52016095, -1.69224449],
#        [ 0.63932333,  0.16897014,  0.45734427, ..., -0.28246883,
#         -1.52016095, -1.69224449],
#        ...,
#        [-1.03768059,  0.33254875, -0.41183481, ...,  0.63250412,
#          2.23275833,  1.79951435],
#        [-1.03768059,  0.33254875, -0.41183481, ...,  0.63250412,
#          2.23275833,  1.79951435],
#        [-1.03768059,  0.33254875, -0.41183481, ...,  0.63250412,
#          2.23275833,  1.79951435]])

# %%
## creating the covariance matrix - this explains the variance between the different
## features within our dataframe

## for example, the value in the i,j position within the matrix explains the variance
## between the ith and the jth elements of a random vector, or between our features
cov_mat = np.cov(Xstand.T)

## creating my eigenvalues and corresponding eigenvectors
eigenValues, eigenVectors = np.linalg.eig(cov_mat)

# %%
print eigenValues 
print
print
print eigenVectors 
## each eigenvector has 8 components - stemming from 8 total features
# Out:
# [  4.25488075e+00   1.83570925e+00   5.37129564e-01   2.13315518e-01
#    1.21931539e-01   5.46721529e-04   3.65468469e-02]
#
#
# [[ 0.44645204  0.01298167  0.41095158  0.33778255  0.54620983 -0.4660478
#    0.04458778]
#  [ 0.43988522  0.12591848 -0.37519719  0.34665762 -0.61449392 -0.38227254
#   -0.07724003]
#  [ 0.47536661  0.06900442  0.06213245  0.35754269  0.02434075  0.79786172
#   -0.01979812]
#  [ 0.36841678  0.31067309  0.53289344 -0.60813005 -0.3375205  -0.0051221
#   -0.00272046]
#  [ 0.39227236  0.17964574 -0.63392084 -0.46869864  0.43688102 -0.00223589
#    0.03802287]
#  [-0.22026875  0.6474918   0.00393109  0.12834297  0.13626756 -0.00423655
#   -0.70509707]
#  [-0.20756036  0.65664177 -0.02527681  0.17866778  0.01027713  0.00588657
#    0.7021673 ]]

# %%
## creating the eigenpairs - just pairing the eigenvalue with its eigenvector
eigenPairs = [(np.abs(eigenValues[i]), eigenVectors[:,i]) for i in range(len(eigenValues))]

## sort in ascending order and then reverse to descending (for clarification's sake)
eigenPairs.sort()
eigenPairs.reverse()

## loop through the eigenpairs and printing out the first row (eigenvalue)
## this is also seen in the code block above but just wanted to loop through again
## as it is a bit more clear like this
## I am also creating a list of the eigenvalues in ascending order to be able to reference it
sort_values = []
for i in eigenPairs:
    print i[0]
    sort_values.append(i[0])
    
sort_values
# Out:
# 4.25488075171
# 1.83570925255
# 0.537129563578
# 0.213315518045
# 0.121931538982
# 0.036546846912
# 0.000546721528772
# [4.2548807517062448,
#  1.8357092525536614,
#  0.53712956357839514,
#  0.21331551804492979,
#  0.12193153898248636,
#  0.036546846912020849,
#  0.00054672152877229571]

# %%
## we have the eigenvalues above showing us feature correlation explanation, but it helps
## to see the cumulative variance explained as well, which i can show below

## need to sum the eigen values to get percentages
sumEigenvalues = sum(eigenValues)

## this is a percentage explanation
variance_explained = [(i/sumEigenvalues)*100 for i in sort_values]
variance_explained
# Out:
# [60.783488058785281,
#  26.224192390645079,
#  7.6732134973925064,
#  3.0473383393031828,
#  1.7418641499551368,
#  0.52209332352551929,
#  0.0078102403932908083]

# %%
### based on the above results, it seems that sticking to 3 features would be ideal
## this can very easily be manipulated by changing n_components adn then adding/subtracting
## columns to the dataframe in the code block below

## instantiate
pca = PCA(n_components = 4)

## fit and transform the standardized data
pca_cols = pca.fit_transform(Xstand)

# %%
## going to organize the columns into dataframe for organization
pca_df = pd.DataFrame(pca_cols, columns = ['pca1', 'pca2', 'pca3', 'pca4'])

##previewing dataframe
print pca_df.shape
pca_df.head()
# Out:
# (116293, 4)
#        pca1      pca2      pca3      pca4
# 0 -1.514379 -1.779891 -0.967131  0.524445
# 1 -1.514379 -1.779891 -0.967131  0.524445
# 2 -1.514379 -1.779891 -0.967131  0.524445
# 3 -1.514379 -1.779891 -0.967131  0.524445
# 4 -1.514379 -1.779891 -0.967131  0.524445

# %%
## Here I am joining the initial dataframe and the newly created pca dataframe
## together to move forward with

final_joined_pca = final_df.join(pca_df)

# %%
print joined_pca.shape
final_joined_pca.head()
# Out:
# (116293, 23)
#          Date  Species  Trap  Latitude  Longitude  AddressAccuracy  day  \
# 0  2008-06-11        2     1  41.95469 -87.800991                9  191
# 1  2008-06-11        3     1  41.95469 -87.800991                9  191
# 2  2008-06-11        1     1  41.95469 -87.800991                9  191
# 3  2008-06-11        4     1  41.95469 -87.800991                9  191
# 4  2008-06-11        6     1  41.95469 -87.800991                9  191
#
#    month  year  Tmax    ...     DewPoint  PrecipTotal  Sunrise  Sunset  \
# 0      6  2008  86.0    ...         55.5          0.0    416.0  1926.0
# 1      6  2008  86.0    ...         55.5          0.0    416.0  1926.0
# 2      6  2008  86.0    ...         55.5          0.0    416.0  1926.0
# 3      6  2008  86.0    ...         55.5          0.0    416.0  1926.0
# 4      6  2008  86.0    ...         55.5          0.0    416.0  1926.0
#
#    month_weather  day_weather      pca1      pca2      pca3      pca4
# 0            6.0        191.0 -1.514379 -1.779891 -0.967131  0.524445
# 1            6.0        191.0 -1.514379 -1.779891 -0.967131  0.524445
# 2            6.0        191.0 -1.514379 -1.779891 -0.967131  0.524445
# 3            6.0        191.0 -1.514379 -1.779891 -0.967131  0.524445
# 4            6.0        191.0 -1.514379 -1.779891 -0.967131  0.524445
#
# [5 rows x 23 columns]

# %%
## now i am going to export the dataframe as a csv file

final_joined_pca.to_csv('/Users/TerryONeill/west_nile/west_nile/assets/final_joined_pca.csv')
